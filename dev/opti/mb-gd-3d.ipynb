# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import numpy as np

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x1 = np.arange(-1, 1, 0.05)
x2 = np.arange(-1, 1, 0.05)
x1, x2 = np.meshgrid(x1, x2)

# %%
y = lambda x1, x2: x1**2 / 2.5 + 2 * x2**2
#y = lambda x1, x2: np.exp(x1 + 3*x2 - 0.1) + np.exp(x1 - 3*x2 - 0.1) - np.exp(x1 - 0.1)
dy = lambda x1, x2: np.array([2*x1, 2*x2])

# %%
_y = y(x1, x2)

fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
ax.plot_surface(x1, x2, _y, rstride=2, cstride=2, cmap=cm.coolwarm)
ax.contourf(x1, x2, _y, zdir='z', offset=0, cmap=cm.coolwarm)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10d908290>

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()
ax.contourf(x1, x2, _y, zdir='z', rstride=10, cstride=5, offset=0, cmap=cm.coolwarm)
plot([0],[0], 'o')

# %%
rate = 0.9

# %%
prev = np.array([-0.9, -0.1])

# %%
grad = dy(prev[0], prev[1])
print grad
new = prev - rate * grad

fig = plt.figure(figsize=(8,6))
ax = fig.gca()
ax.contourf(x1, x2, _y, zdir='z', rstride=10, cstride=5, offset=0, cmap=cm.coolwarm)

plot(-0.9, -0.1, 'o')
plot(new[0], new[1], 'o')
prev = new
# Out:
# [-0.0506655 -0.0056295]
