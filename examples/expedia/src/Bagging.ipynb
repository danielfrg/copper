# %%
import copper
import pandas as pd

# %%
train = copper.read_csv('train.csv')
train.role['depend'] = train.TARGET
train.fillna(method='mean')

# %%
test = copper.read_csv('test.csv')
test.role['depend'] = test.TARGET
test.fillna(method='mean')

# %%
ml = copper.MachineLearning()
ml.train = train
ml.test = test

# %%
from sklearn.naive_bayes import GaussianNB
gnb_clf = GaussianNB()

# %%
ml.bootstrap(GaussianNB, "GNB", 10)

# %%
ml.accuracy().head()
# Out:
# GNB_1     0.829465
# GNB_5     0.826149
# GNB_8     0.819043
# GNB_10    0.811937
# GNB_9     0.796779
# Name: Accuracy

# %%
ml.roc()
# Out:
# /home/dfrodriguez/.virtualenvs/copper/lib/python3.2/site-packages/matplotlib/figure.py:1527: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ml.bagging('Bag')

# %%
ml.accuracy().head()
# Out:
# GNB_1     0.829465
# GNB_5     0.826149
# Bag       0.824254
# GNB_8     0.819043
# GNB_10    0.811937
# Name: Accuracy

# %%
ml.roc()

# %% [markdown]
# # Desicion tree

# %%
ml2 = copper.MachineLearning()

# %%
ml2.train = train

# %%
ml2.test = test

# %%
from sklearn import tree

# %%
ml2.bootstrap(tree.DecisionTreeClassifier, "DT", 10, max_depth=7)

# %%
ml2.accuracy().head()
# Out:
# DT_4     0.837991
# DT_7     0.833728
# DT_1     0.828991
# DT_9     0.826149
# DT_10    0.825201
# Name: Accuracy

# %%
ml2.roc()

# %%
ml2.bagging('Bag')

# %%
ml2.accuracy().head()
# Out:
# Bag     0.874467
# DT_4    0.837991
# DT_7    0.833728
# DT_1    0.828991
# DT_9    0.826149
# Name: Accuracy

# %%
ml2.roc()
